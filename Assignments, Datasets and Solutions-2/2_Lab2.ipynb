# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 1:
# - Import the boston house dataset from `sklearn.datasets`.
#
# `from sklearn.datasets import load_boston`
#
# `boston = load_boston()`
#
# - Create train and test datasets.
#
# - Check the data description and familiarize yourself with the data.

# %%
#loading dataset
name= ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv(filepath_or_buffer="http://lib.stat.cmu.edu/datasets/boston", delim_whitespace=True, names=name)
df.head()
# Out:
#      CRIM       ZN        INDUS    CHAS      NOX               RM    AGE  \
# 0     The   Boston  house-price    data       of        Harrison,     D.
# 1  prices      and          the  demand      for            clean  air',
# 2  vol.5,  81-102,        1978.    Used       in         Belsley,    Kuh
# 3   ...',   Wiley,        1980.    N.B.  Various  transformations    are
# 4   pages  244-261           of     the  latter.              NaN    NaN
#
#     DIS         RAD          TAX      PTRATIO            B LSTAT  MEDV
# 0   and  Rubinfeld,         D.L.     'Hedonic          NaN   NaN   NaN
# 1    J.    Environ.    Economics            &  Management,   NaN   NaN
# 2     &     Welsch,  'Regression  diagnostics          NaN   NaN   NaN
# 3  used          in          the        table           on   NaN   NaN
# 4   NaN         NaN          NaN          NaN          NaN   NaN   NaN

# %%
df.shape
# Out:
# (1032, 14)

# %%
from sklearn.model_selection import train_test_split
X, y = df.data, df.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-c6411b6f7e8b> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X, y = df.data, df.target
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %% [markdown]
# ### Step 2:
# Create a scatter plot of each attribute with the mean house price.

# %% [markdown]
# ### Step 3:
# Create a box plot of all attributes.

# %% [markdown]
# ### Step 4:
# Use `StandardScaler()` to scale the trainin data set.

# %% [markdown]
# ### Step 5:
# Use `KNeighborsRegressor()` to fit both not-scaled and scaled datasets. Check the scores of test dataset for both models.

# %% [markdown]
# ### Step 6:
# Repeat Step 5 for `RandomForestRegressor`. Use
#
# `RandomForestRegressor(n_estimators=100, random_state=0)`
